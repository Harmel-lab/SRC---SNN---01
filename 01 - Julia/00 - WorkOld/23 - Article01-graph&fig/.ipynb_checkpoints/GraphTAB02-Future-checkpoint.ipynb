# %%
# utilisation si nécessaire pour affichage de résultats
using Plots
gr()  # backend conseillé

# -- valeurs de mesure code Florent
x1 = [0.8  , 0.81, 0.82, 0.83, 0.84, 0.85, 0.86, 0.87, 0.88, 0.88, 0.90, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.98, 0.99,0.992,0.994,0.996]
y1 = [0]

# -- valeurs de mesure code PsV
y2 = [96.04,96.16,96.16,96.18,96.16,96.03,96.23,96.26,96.29,96.30,96.48,96.15,96.40,96.38,96.55,96.04,95.99,95.68,95.36,93.14,90.36,91.36,90.97]

#-- valeur de mesure code FPGA
x3= [ 800 ,  810,  820,  830,  840,  850,  860,  870,  880,  890,  900,  910,  910,  920,  930,  940,  950,  960,  970,  980,  990, 1000, 1010]
y3= [96.23,96.12,96.21,96.21,96.24,96.28,96.17,96.23,96.13,96.22,96.31,96.22,96.07,96.26,96.15,96.28,96.20,96.02,94.58,95.58,94.63,93.23,88.26]


#x = [0.8  , 0.81, 0.82, 0.83, 0.84, 0.85, 0.86, 0.87, 0.88, 0.88, 0.90, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.98, 0.99,0.992,0.994,0.996,0.998]
#y = [96.04,96.16,96.16,96.18,96.16,96.03,96.23,96.26,96.29,96.30,96.48,96.15,96.40,96.38,96.55,96.04,95.99,95.68,95.36,93.14,90.36,91.36,90.97,67.13]

#x2= [ 800 ,  810,  820,  830,  840,  850,  860,  870,  880,  890,  900,  910,  910,  920,  930,  940,  950,  960,  970,  980,  990, 1000, 1010,1020]
#y2= [96.23,96.12,96.21,96.21,96.24,96.28,96.17,96.23,96.13,96.22,96.31,96.22,96.07,96.26,96.15,96.28,96.20,96.02,94.58,95.58,94.63,93.23,88.26,9.80]

# --- Graphique du bas (rouge) ---

p1 = plot(
    x1, y2,
    color = :red,
    label = "Courbe 1",
    xlabel = "Zhyp - [5]", xguidefontcolor = :red,
    ylabel = "MNIST accuracy (%)",
    xlims = extrema(x1),
    x_foreground_color_axis  = :red,
    x_foreground_color_text  = :red,
    y_foreground_color_axis  = :black,
    y_foreground_color_text  = :black,
    legend = false,
)

# --- Deuxième axe X en haut, en bleu ---
p2 = twiny()  # crée un second axe X, en haut
p2 = plot!(p2,
    x3, y3,
    linestyle=:dash,
    color = :blue,
    label = "Courbe 2",
    xlabel = "Zhyp - VHDL", xguidefontcolor = :blue,
    xlims = extrema(x3),
    x_foreground_color_axis  = :blue,
    x_foreground_color_text  = :blue,
    y_foreground_color_axis  = :black,
    y_foreground_color_text  = :black,
    legend = false)

# Superposition (axes indépendants)
plot(p2)
savefig("Table-01Future.pdf")
savefig("Table-01Future.png")
# Out:
# BoundsError: attempt to access 0-element Vector{Float64} at index [1:23]
#
# Stacktrace:
#   [1] throw_boundserror(A::Vector{Float64}, I::Tuple{UnitRange{Int64}})
#     @ Base .\essentials.jl:15
#   [2] checkbounds
#     @ .\abstractarray.jl:699 [inlined]
#   [3] getindex(A::Vector{Float64}, I::UnitRange{Int64})
#     @ Base .\array.jl:935
#   [4] gr_draw_segments(series::Plots.Series, x::Vector{Float64}, y::Vector{Float64}, z::Nothing, fillrange::Nothing, clims::Tuple{Float64, Float64})
#     @ Plots C:\Users\Pascal\.julia\packages\Plots\xKhUG\src\backends\gr.jl:1858
#   [5] gr_add_series(sp::Plots.Subplot{Plots.GRBackend}, series::Plots.Series)
#     @ Plots C:\Users\Pascal\.julia\packages\Plots\xKhUG\src\backends\gr.jl:1775
#   [6] gr_display(sp::Plots.Subplot{Plots.GRBackend}, w::Measures.AbsoluteLength, h::Measures.AbsoluteLength, vp_canvas::Plots.GRViewport{Float64})
#     @ Plots C:\Users\Pascal\.julia\packages\Plots\xKhUG\src\backends\gr.jl:966
#   [7] (::Plots.var"#gr_display##0#gr_display##1"{Int64, Int64, Plots.GRViewport{Float64}})(sp::Plots.Subplot{Plots.GRBackend})
#     @ Plots C:\Users\Pascal\.julia\packages\Plots\xKhUG\src\backends\gr.jl:690
#   [8] foreach(f::Plots.var"#gr_display##0#gr_display##1"{Int64, Int64, Plots.GRViewport{Float64}}, itr::Vector{Plots.Subplot})
#     @ Base .\abstractarray.jl:3188
#   [9] gr_display(plt::Plots.Plot{Plots.GRBackend}, dpi_factor::Int64)
#     @ Plots C:\Users\Pascal\.julia\packages\Plots\xKhUG\src\backends\gr.jl:690
#  [10] #_show##0
#     @ C:\Users\Pascal\.julia\packages\Plots\xKhUG\src\backends\gr.jl:2098 [inlined]
#  [11] withenv(::Plots.var"#_show##0#_show##1"{Plots.Plot{Plots.GRBackend}, Int64}, ::Pair{String, String}, ::Vararg{Pair{String, String}})
#     @ Base .\env.jl:265
#  [12] _show(io::IOStream, ::MIME{Symbol("application/pdf")}, plt::Plots.Plot{Plots.GRBackend})
#     @ Plots C:\Users\Pascal\.julia\packages\Plots\xKhUG\src\backends\gr.jl:2093
#  [13] show
#     @ C:\Users\Pascal\.julia\packages\Plots\xKhUG\src\output.jl:239 [inlined]
#  [14] #pdf##0
#     @ C:\Users\Pascal\.julia\packages\Plots\xKhUG\src\output.jl:26 [inlined]
#  [15] open(::Plots.var"#pdf##0#pdf##1"{Plots.Plot{Plots.GRBackend}}, ::String, ::Vararg{String}; kwargs::@Kwargs{})
#     @ Base .\io.jl:410
#  [16] open
#     @ .\io.jl:407 [inlined]
#  [17] pdf(plt::Plots.Plot{Plots.GRBackend}, fn::String)
#     @ Plots C:\Users\Pascal\.julia\packages\Plots\xKhUG\src\output.jl:26
#  [18] savefig(plt::Plots.Plot{Plots.GRBackend}, fn::String)
#     @ Plots C:\Users\Pascal\.julia\packages\Plots\xKhUG\src\output.jl:148
#  [19] savefig(fn::String)
#     @ Plots C:\Users\Pascal\.julia\packages\Plots\xKhUG\src\output.jl:153
#  [20] top-level scope
#     @ In[6]:55
#  [21] eval(m::Module, e::Any)
#     @ Core .\boot.jl:489
